# %%
# !pip3 install pandas
# !pip3 install pycaret full
# !pip3 install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycaret in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (3.0.4)
# Requirement already satisfied: full in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (0.0.3.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: psutil>=5.9.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (5.9.4)
# Requirement already satisfied: plotly>=5.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (5.15.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (4.0.0)
# Requirement already satisfied: schemdraw==0.15 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.15)
# Requirement already satisfied: requests>=2.27.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.1.3)
# Requirement already satisfied: xxhash in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: tbats>=1.1.3 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: ipython>=5.5.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.6.1)
# Requirement already satisfied: pyod>=1.0.8 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.21.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: jinja2>=1.2 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: scipy<2.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.11.1)
# Requirement already satisfied: numba>=0.55.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (0.57.1)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.5)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (8.1.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (3.7.2)
# Requirement already satisfied: wurlitzer in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (4.66.1)
# Requirement already satisfied: cloudpickle in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: torch in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from full) (2.0.1)
# Requirement already satisfied: transformers in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from full) (4.31.0)
# Requirement already satisfied: patsy>=0.5.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: packaging in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from deprecation>=2.1.0->pycaret) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.16.2)
# Requirement already satisfied: backcall in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: appnope in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.1.3)
# Requirement already satisfied: decorator in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (5.8.0)
# Requirement already satisfied: stack-data in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (0.6.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.8)
# Requirement already satisfied: comm>=0.1.3 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (4.42.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (10.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (6.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: jupyter-core in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.2.0->pycaret) (5.1.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.2.0->pycaret) (4.19.0)
# Requirement already satisfied: fastjsonschema in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from nbformat>=4.2.0->pycaret) (2.18.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.9.2)
# Requirement already satisfied: referencing>=0.28.4 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from numba>=0.55.0->pycaret) (0.40.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2023.3)
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from plotly>=5.0.0->pycaret) (8.2.2)
# Requirement already satisfied: tsdownsample==0.1.2 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.11.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.4)
# Requirement already satisfied: trace-updater>=0.0.8 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.7.1)
# Requirement already satisfied: ansi2html in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: nest-asyncio in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.6)
# Requirement already satisfied: urllib3 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (2.0.4)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (58.0.4)
# Requirement already satisfied: wcwidth in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->pycaret) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->pycaret) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: scikit-base<0.6.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (0.5.0)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.6.0)
# Requirement already satisfied: pure-eval in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.5.0->pycaret) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: networkx in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from torch->full) (3.1)
# Requirement already satisfied: filelock in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from torch->full) (3.12.2)
# Requirement already satisfied: sympy in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from torch->full) (1.12)
# Requirement already satisfied: mpmath>=0.19 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from sympy->torch->full) (1.3.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from transformers->full) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from transformers->full) (0.3.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from transformers->full) (2023.8.8)
# Requirement already satisfied: pyyaml>=5.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from transformers->full) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from transformers->full) (0.16.4)
# Requirement already satisfied: fsspec in /Users/stefanbund/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers->full) (2023.6.0)
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import pandas as pd
from pycaret.classification import *

# %%
m2 = pd.read_csv('nan_cols.csv')
m2.columns
# Out:
# Index(['group_1', 'time_1', 's_MP', 'change_1', 'type_1', 'length_1',
#        'sum_change_1', 'area_1', 'surge_area', 'group_1.1', 'time_1.1',
#        'change_1.1', 'type_1.1', 'p_MP', 'p_buyCap', 'p_askCap',
#        'p_totalBidVol', 'p_totalAskVol', 'length_1.1', 'sum_change_1.1',
#        'area_1.1'],
#       dtype='object')

# %%
# s = setup(m2, target = 'area', session_id = 1)

from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(m2, target = 'area_1', session_id = 1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[38], line 5
#       3 from pycaret.classification import ClassificationExperiment
#       4 s = ClassificationExperiment()
# ----> 5 s.setup(m2, target = 'area_1', session_id = 1)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/classification/oop.py:722, in ClassificationExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, group_names, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, fix_imbalance, fix_imbalance_method, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     719 self.fold_shuffle_param = fold_shuffle
#     720 self.fold_groups_param = fold_groups
# --> 722 self._initialize_setup(
#     723     n_jobs=n_jobs,
#     724     use_gpu=use_gpu,
#     725     html=html,
#     726     session_id=session_id,
#     727     system_log=system_log,
#     728     log_experiment=log_experiment,
#     729     experiment_name=experiment_name,
#     730     memory=memory,
#     731     verbose=verbose,
#     732 )
#     734 # Prepare experiment specific params ======================= >>
#     736 self.log_plots_param = log_plots
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:330, in _TabularExperiment._initialize_setup(self, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, memory, verbose)
#     326 self.logger.info(f"self.USI: {self.USI}")
#     328 self.logger.info(f"self._variable_keys: {self._variable_keys}")
# --> 330 self._check_environment()
#     332 # Set up GPU usage ========================================= >>
#     334 if self.gpu_param != "force" and type(self.gpu_param) is not bool:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/internal/pycaret_experiment/pycaret_experiment.py:121, in _PyCaretExperiment._check_environment(self)
#     118 from pycaret.utils._show_versions import show_versions
#     120 self.logger.info("Checking libraries")
# --> 121 self.logger.info(show_versions(logger=self.logger))
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/utils/_show_versions.py:165, in show_versions(optional, logger)
#     162     print_func("{k:>10}: {stat}".format(k=k, stat=stat))  # noqa: T001
#     164 print_func(f"{prefix}PyCaret required dependencies:")  # noqa: T001
# --> 165 optional_deps_info = _get_deps_info(logger=logger)
#     166 for k, stat in optional_deps_info.items():
#     167     print_func("{k:>20}: {stat}".format(k=k, stat=stat))  # noqa: T001
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/utils/_show_versions.py:130, in _get_deps_info(optional, logger)
#     128 for modname in deps:
#     129     try:
# --> 130         ver = get_module_version(modname)
#     131         if not ver:
#     132             ver = "Installed but version unavailable"
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/utils/_dependencies.py:81, in get_module_version(modname)
#      79 def get_module_version(modname: str) -> Optional[LooseVersion]:
#      80     """Raises a ValueError if module is not installed"""
# ---> 81     version = _get_module_version(modname)
#      82     if version is False:
#      83         raise ValueError(f"Module '{modname}' is not installed.")
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/utils/_dependencies.py:75, in _get_module_version(modname)
#      72 installed_modules = get_installed_modules()
#      73 if modname not in installed_modules:
#      74     # Fallback. This should never happen unless module is not present
# ---> 75     installed_modules[modname] = _try_import_and_get_module_version(modname)
#      76 return installed_modules[modname]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pycaret/utils/_dependencies.py:28, in _try_import_and_get_module_version(modname)
#      26 if logger:
#      27     with redirect_output(logger):
# ---> 28         mod = import_module(modname)
#      29 else:
#      30     mod = import_module(modname)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File ~/Library/Python/3.9/lib/python/site-packages/lightgbm/basic.py:221
#     219     _LIB = Mock(ctypes.CDLL)  # type: ignore
#     220 else:
# --> 221     _LIB = _load_lib()
#     224 _NUMERIC_TYPES = (int, float, bool)
#     225 _ArrayLike = Union[List, np.ndarray, pd_Series]
#
# File ~/Library/Python/3.9/lib/python/site-packages/lightgbm/basic.py:206, in _load_lib()
#     204 """Load LightGBM library."""
#     205 lib_path = find_lib_path()
# --> 206 lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     207 lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     208 callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:444, in LibraryLoader.LoadLibrary(self, name)
#     443 def LoadLibrary(self, name):
# --> 444     return self._dlltype(name)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:366, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     363 self._FuncPtr = _FuncPtr
#     365 if handle is None:
# --> 366     self._handle = _dlopen(self._name, mode)
#     367 else:
#     368     self._handle = handle
#
# OSError: dlopen(/Users/stefanbund/Library/Python/3.9/lib/python/site-packages/lightgbm/lib/lib_lightgbm.so, 0x0006): Library not loaded: '/usr/local/opt/libomp/lib/libomp.dylib'
#   Referenced from: '/Users/stefanbund/Library/Python/3.9/lib/python/site-packages/lightgbm/lib/lib_lightgbm.so'
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)
